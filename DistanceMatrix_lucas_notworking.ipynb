# %%
import googlemaps as gmaps
import pandas as pd
import numpy as np
import os

api_key = 'API_HERE'
gmaps = gmaps.Client(key=api_key)

# %%
help(gmaps.distance_matrix)
# Out:
# Help on method distance_matrix in module googlemaps.distance_matrix:
#
# distance_matrix(origins, destinations, mode=None, language=None, avoid=None, units=None, departure_time=None, arrival_time=None, transit_mode=None, transit_routing_preference=None, traffic_model=None, region=None) method of googlemaps.client.Client instance
#     Gets travel distance and time for a matrix of origins and destinations.
#
#     :param origins: One or more addresses, Place IDs, and/or latitude/longitude
#         values, from which to calculate distance and time. Each Place ID string
#         must be prepended with 'place_id:'. If you pass an address as a string,
#         the service will geocode the string and convert it to a
#         latitude/longitude coordinate to calculate directions.
#     :type origins: a single location, or a list of locations, where a
#         location is a string, dict, list, or tuple
#
#     :param destinations: One or more addresses, Place IDs, and/or lat/lng values
#         , to which to calculate distance and time. Each Place ID string must be
#         prepended with 'place_id:'. If you pass an address as a string, the
#         service will geocode the string and convert it to a latitude/longitude
#         coordinate to calculate directions.
#     :type destinations: a single location, or a list of locations, where a
#         location is a string, dict, list, or tuple
#
#     :param mode: Specifies the mode of transport to use when calculating
#         directions. Valid values are "driving", "walking", "transit" or
#         "bicycling".
#     :type mode: string
#
#     :param language: The language in which to return results.
#     :type language: string
#
#     :param avoid: Indicates that the calculated route(s) should avoid the
#         indicated features. Valid values are "tolls", "highways" or "ferries".
#     :type avoid: string
#
#     :param units: Specifies the unit system to use when displaying results.
#         Valid values are "metric" or "imperial".
#     :type units: string
#
#     :param departure_time: Specifies the desired time of departure.
#     :type departure_time: int or datetime.datetime
#
#     :param arrival_time: Specifies the desired time of arrival for transit
#         directions. Note: you can't specify both departure_time and
#         arrival_time.
#     :type arrival_time: int or datetime.datetime
#
#     :param transit_mode: Specifies one or more preferred modes of transit.
#         This parameter may only be specified for requests where the mode is
#         transit. Valid values are "bus", "subway", "train", "tram", "rail".
#         "rail" is equivalent to ["train", "tram", "subway"].
#     :type transit_mode: string or list of strings
#
#     :param transit_routing_preference: Specifies preferences for transit
#         requests. Valid values are "less_walking" or "fewer_transfers".
#     :type transit_routing_preference: string
#
#     :param traffic_model: Specifies the predictive travel time model to use.
#         Valid values are "best_guess" or "optimistic" or "pessimistic".
#         The traffic_model parameter may only be specified for requests where
#         the travel mode is driving, and where the request includes a
#         departure_time.
#
#     :param region: Specifies the prefered region the geocoder should search
#         first, but it will not restrict the results to only this region. Valid
#         values are a ccTLD code.
#     :type region: string
#
#     :rtype: matrix of distances. Results are returned in rows, each row
#         containing one origin paired with each destination.

# %%
data_files = {}
for x in os.listdir("./Data/"):
    if not x in ["aeds.csv", "cards.csv", "vehicles.csv"]:
        data_files[x] = pd.read_csv("./Data/" + x)

# %%
#replacing the "POINT " in the dataframes to fit them in with the distance matrix function
rpp = lambda x: x.replace('POINT ', '')
for key, df in data_files.items():
    df['geometry'] = df['geometry'].apply(lambda x: tuple(map(float, reversed(x.replace('POINT ', '').strip('()').split()))))

# %%
data_files["Antwerpen_aeds.csv"]["geometry"].tolist()
# Out:
# [(51.1967334, 4.4294545),
#  (51.227416, 4.4043543),
#  (51.2292299, 4.4376834),
#  (51.1864481, 4.3712851),
#  (51.2035955, 4.420659),
#  (51.1898934, 4.4393053),
#  (51.1739816, 4.3955885),
#  (51.1683102, 4.3942868),
#  (51.1516862, 4.3824848),
#  (51.1516862, 4.3824848),
#  (51.1932753, 4.422559),
#  (51.1932753, 4.422559),
#  (51.2083908, 4.4212001),
#  (51.2145513, 4.4136852),
#  (51.1940075, 4.4115464),
#  (51.1961723, 4.346706),
#  (51.2017907, 4.3909155),
#  (51.2152392, 4.4046611),
#  (51.1783874, 4.4155625),
#  (51.2232215, 4.4113175),
#  (51.2128059, 4.4250631),
#  (51.2164375, 4.4093125),
#  (51.2192904, 4.4034402),
#  (51.1700028, 4.3613276),
#  (51.1923982, 4.4347991),
#  (51.2169691, 4.4207019),
#  (51.1985891, 4.4422221),
#  (51.1670191, 4.3541959),
#  (51.194908, 4.4044371),
#  (51.234858, 4.3932715),
#  (51.2158658, 4.403616),
#  (51.3049232, 4.3084317),
#  (51.2169691, 4.4207019),
#  (51.2277048, 4.4094452),
#  (51.2015719, 4.4346337),
#  (51.2190615, 4.4077349),
#  (51.2863112, 4.3834359),
#  (51.2265417, 4.4015541),
#  (51.2745613, 4.3874516),
#  (51.2742319, 4.3896804),
#  (51.1914025, 4.3995071),
#  (51.1711748, 4.3934914),
#  (51.1693402, 4.3939156),
#  (51.1919212, 4.4195521),
#  (51.2156817, 4.410283),
#  (51.218672, 4.417298),
#  (51.1683102, 4.3942868),
#  (51.1558939, 4.3751209),
#  (51.1558232, 4.3745109),
#  (51.1887405, 4.4616926),
#  (51.1983132, 4.4172255),
#  (51.1751862, 4.3314201),
#  (51.2209191, 4.4093694),
#  (51.2639472, 4.4100517),
#  (51.1942464, 4.4346473),
#  (51.2408744, 4.4072919),
#  (51.2451448, 4.4084652),
#  (51.2288381, 4.4053281),
#  (51.2367147, 4.4037904),
#  (51.2772824, 4.3324851),
#  (51.3104021, 4.3238285),
#  (51.3448238, 4.2863967),
#  (51.2189962, 4.4027787),
#  (51.1836528, 4.3719871),
#  (51.1703986, 4.3936351),
#  (51.201775, 4.4055061),
#  (51.185354, 4.4318872),
#  (51.2268325, 4.4327997),
#  (51.2151764, 4.4187768),
#  (51.1902522, 4.4391631),
#  (51.2045492, 4.4105192),
#  (51.2060583, 4.4323018),
#  (51.2060583, 4.4323018),
#  (51.2121808, 4.3983143),
#  (51.2134803, 4.423794),
#  (51.2677978, 4.4016567),
#  (51.2677978, 4.4016567),
#  (51.2147717, 4.4110964),
#  (51.213518, 4.4226425),
#  (51.2158876, 4.4085722),
#  (51.2187495, 4.4105195),
#  (51.2304425, 4.4033957),
#  (51.2217778, 4.4000328),
#  (51.2165323, 4.4117879),
#  (51.2193373, 4.4179202),
#  (51.2011323, 4.4171313),
#  (51.2361031, 4.4539142),
#  (51.1968852, 4.396798),
#  (51.3577063, 4.3171467),
#  (51.220503, 4.4001113),
#  (51.1976073, 4.4287562),
#  (51.2152645, 4.4075721),
#  (51.2310221, 4.4045309),
#  (51.1721718, 4.4072275),
#  (51.1721718, 4.4072275),
#  (51.2641549, 4.4016149),
#  (51.2064663, 4.406),
#  (51.2099212, 4.4207989),
#  (51.2090167, 4.4176617),
#  (51.2139123, 4.4388449),
#  (51.1923982, 4.4347991),
#  (51.1937154, 4.381543),
#  (51.2361773, 4.4396549),
#  (51.1947103, 4.4113181),
#  (51.25792, 4.37439),
#  (51.3200125, 4.2951339),
#  (51.3200125, 4.2951339),
#  (51.2304425, 4.4033957),
#  (51.2544695, 4.4196264),
#  (51.2154141, 4.4185),
#  (51.2188663, 4.4034381),
#  (51.2501156, 4.3673786),
#  (51.2460078, 4.4165549),
#  (51.1911829, 4.4498723),
#  (51.2137103, 4.4126365),
#  (51.1995502, 4.3589102),
#  (51.1995502, 4.3589102),
#  (51.1560493, 4.3733119),
#  (51.210302, 4.4469787),
#  (51.2569663, 4.3448672),
#  (51.2151342, 4.4127668),
#  (51.2149228, 4.4205059),
#  (51.1650496, 4.4089077),
#  (51.2144151, 4.4172113),
#  (51.2132602, 4.416971),
#  (51.2194426, 4.4025645),
#  (51.2100204, 4.4053841),
#  (51.2217763, 4.348097),
#  (51.1946999, 4.4063686),
#  (51.1726789, 4.4274853),
#  (51.1928344, 4.4167589),
#  (51.1878134, 4.436941),
#  (51.2142667, 4.4185165),
#  (51.2142667, 4.4185165),
#  (51.1845547, 4.4212374),
#  (51.2290024, 4.4046541),
#  (51.2640771, 4.3994951),
#  (51.2848163, 4.438111),
#  (51.2377151, 4.4462165),
#  (51.2357978, 4.4691895),
#  (51.1650496, 4.4089077),
#  (51.1948926, 4.4732427),
#  (51.207323, 4.4050403),
#  (51.2179665, 4.4114404),
#  (51.237544, 4.4103806),
#  (51.2463099, 4.4427015),
#  (51.2142667, 4.4185165),
#  (51.2437434, 4.4241174),
#  (51.2185836, 4.3692106),
#  (51.1899382, 4.3957278),
#  (51.1899382, 4.3957278),
#  (51.1924427, 4.3977482),
#  (51.1977075, 4.4100678),
#  (51.1961723, 4.346706),
#  (51.1980351, 4.3752089),
#  (51.227899, 4.4064889),
#  (51.2056476, 4.3877966),
#  (51.2470732, 4.428731),
#  (51.181794, 4.3353581),
#  (51.2060797, 4.3872888),
#  (51.2056476, 4.3877966),
#  (51.2073005, 4.3880113),
#  (51.1886764, 4.3717464),
#  (51.1940097, 4.4344117),
#  (51.2130916, 4.4231599),
#  (51.2167179, 4.4112526),
#  (51.3162828, 4.335163),
#  (51.2032621, 4.4121241),
#  (51.2032621, 4.4121241),
#  (51.21458, 4.4050147),
#  (51.2471112, 4.4177207),
#  (51.3162828, 4.335163),
#  (51.2056884, 4.4102319),
#  (51.2100601, 4.4301283),
#  (51.2144309, 4.4432549),
#  (51.2162391, 4.4033343),
#  (51.1836404, 4.3704733),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.2659275, 4.381065),
#  (51.2642465, 4.3903404),
#  (51.1563774, 4.3673405),
#  (51.1945567, 4.4626515),
#  (51.1823046, 4.3338392),
#  (51.2299448, 4.4160739),
#  (51.2162156, 4.4107747),
#  (51.2196237, 4.4121547),
#  (51.23017, 4.4139014),
#  (51.1986336, 4.4181679),
#  (51.2805456, 4.4302736),
#  (51.2805456, 4.4302736),
#  (51.2805456, 4.4302736),
#  (51.155958, 4.3784068),
#  (51.2717913, 4.3845025),
#  (51.2161877, 4.4025767),
#  (51.2218731, 4.4106836),
#  (51.2199274, 4.4046761),
#  (51.214227, 4.4230825),
#  (51.2729363, 4.3743373),
#  (51.2639275, 4.4139295),
#  (51.3027649, 4.3387065),
#  (51.2631085, 4.406576),
#  (51.2631085, 4.406576),
#  (51.2711695, 4.3796382),
#  (51.1783874, 4.4155625),
#  (51.193325, 4.403597),
#  (51.1930371, 4.4025538),
#  (51.2270677, 4.4074162),
#  (51.2356105, 4.4641649),
#  (51.216152, 4.4018972),
#  (51.2641549, 4.4016149),
#  (51.1650496, 4.4089077),
#  (51.2233443, 4.4385926),
#  (51.2242654, 4.4118785),
#  (51.213104, 4.4342755),
#  (51.213104, 4.4342755),
#  (51.2161877, 4.4025767),
#  (51.2617269, 4.4203774),
#  (51.2617269, 4.4203774),
#  (51.2617269, 4.4203774),
#  (51.2617269, 4.4203774),
#  (51.2670712, 4.3983629),
#  (51.1764218, 4.3872745),
#  (51.1595891, 4.4068876),
#  (51.3168405, 4.3368564),
#  (51.2697864, 4.3766281),
#  (51.3219226, 4.3484454),
#  (51.2265676, 4.4162079),
#  (51.1556103, 4.3894709),
#  (51.217589, 4.41777),
#  (51.2098583, 4.3889581),
#  (51.2625889, 4.3837117),
#  (51.2104827, 4.4188834),
#  (51.276002, 4.3319185),
#  (51.1769423, 4.4055698),
#  (51.2807128, 4.3313814),
#  (51.2729363, 4.3743373),
#  (51.2398198, 4.4111945),
#  (51.2519719, 4.3937929),
#  (51.2264023, 4.412241),
#  (51.218177, 4.4170563),
#  (51.2727718, 4.3810483),
#  (51.2284736, 4.4057268),
#  (51.1491512, 4.3802323),
#  (51.2143553, 4.4180263),
#  (51.1491512, 4.3802323),
#  (51.1491512, 4.3802323),
#  (51.2329898, 4.4699265),
#  (51.2371797, 4.4208867),
#  (51.2366284, 4.4795812),
#  (51.2035103, 4.4409696),
#  (51.2177456, 4.4218399),
#  (51.2177456, 4.4218399),
#  (51.264077, 4.399495),
#  (51.1581154, 4.390484),
#  (51.1580998, 4.3650427),
#  (51.2639472, 4.4100517),
#  (51.1745279, 4.366771),
#  (51.2548833, 4.444965),
#  (51.2724096, 4.3945498),
#  (51.2724096, 4.3945498),
#  (51.251482, 4.4211623),
#  (51.2642788, 4.4621572),
#  (51.1755846, 4.3501009),
#  (51.1824512, 4.3896799),
#  (51.2638454, 4.4043052),
#  (51.1926823, 4.4177341),
#  (51.3027851, 4.3406425),
#  (51.2199162, 4.4195545),
#  (51.2173823, 4.4249515),
#  (51.2168373, 4.4251572),
#  (51.217066, 4.4251298),
#  (51.2249809, 4.411211),
#  (51.2224915, 4.3827544),
#  (51.2128935, 4.4220741),
#  (51.2106538, 4.442346),
#  (51.2583771, 4.4189091),
#  (51.2231547, 4.3772207),
#  (51.1838628, 4.3793852),
#  (51.2190835, 4.4072262),
#  (51.2605408, 4.4136986),
#  (51.2130611, 4.4011684),
#  (51.1558065, 4.3675352),
#  (51.1558065, 4.3675352),
#  (51.2569663, 4.3448672),
#  (51.2569663, 4.3448672),
#  (51.2569663, 4.3448672),
#  (51.2068389, 4.4234258),
#  (51.2200597, 4.4428707),
#  (51.204951, 4.4374368),
#  (51.2195886, 4.4104241),
#  (51.2388518, 4.4366581),
#  (51.2229172, 4.4036671),
#  (51.290811, 4.349123),
#  (51.2360511, 4.4565612),
#  (51.2569663, 4.3448672),
#  (51.2569663, 4.3448672),
#  (51.2569663, 4.3448672),
#  (51.2569663, 4.3448672),
#  (51.2569663, 4.3448672),
#  (51.1928255, 4.4157228),
#  (51.2617269, 4.4203774),
#  (51.2617269, 4.4203774),
#  (51.2617269, 4.4203774),
#  (51.239442, 4.4557629),
#  (51.2617269, 4.4203774),
#  (51.3449382, 4.3212671),
#  (51.2116644, 4.422739),
#  (51.2405097, 4.3980054),
#  (51.1924427, 4.3977482),
#  (51.2203379, 4.4095746),
#  (51.1595891, 4.4068876),
#  (51.2208928, 4.4144154),
#  (51.2265676, 4.4162079),
#  (51.1742096, 4.4080305),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.3149758, 4.2893042),
#  (51.2191172, 4.4498012),
#  (51.290827, 4.3779359),
#  (51.290827, 4.3779359),
#  (51.2254873, 4.4388693),
#  (51.2254873, 4.4388693),
#  (51.2617269, 4.4203774),
#  (51.2205923, 4.4108153),
#  (51.2177456, 4.4218399),
#  (51.2177456, 4.4218399),
#  (51.1910575, 4.4384162),
#  (51.1916778, 4.4376045),
#  (51.1893469, 4.4395213),
#  (51.2617269, 4.4203774),
#  (51.2617269, 4.4203774),
#  (51.2617269, 4.4203774),
#  (51.2617269, 4.4203774),
#  (51.2192478, 4.405051),
#  (51.268978, 4.3756209),
#  (51.2216854, 4.4064208),
#  (51.2075189, 4.4260567),
#  (51.2154141, 4.4185),
#  (51.2552821, 4.437768),
#  (51.2294619, 4.4564007),
#  (51.2195892, 4.448516),
#  (51.200631, 4.4358098),
#  (51.2507044, 4.4195035),
#  (51.220533, 4.4075994),
#  (51.2123782, 4.4389432),
#  (51.2490988, 4.4630307),
#  (51.2001158, 4.4338797),
#  (51.2277566, 4.4061906),
#  (51.1697494, 4.3799179),
#  (51.2270677, 4.4074162),
#  (51.2178577, 4.4063282),
#  (51.2285544, 4.4118979),
#  (51.3149758, 4.2893042),
#  (51.2208824, 4.4046486),
#  (51.2131373, 4.4111901),
#  (51.2279048, 4.4059538),
#  (51.2213974, 4.3776074),
#  (51.1722415, 4.3857895),
#  (51.2426331, 4.3606268),
#  (51.1637672, 4.4105981),
#  (51.1845547, 4.4212374),
#  (51.2226565, 4.4060399),
#  (51.2224479, 4.4101059),
#  (51.2237211, 4.413278),
#  (51.2154128, 4.4149561),
#  (51.2116213, 4.3895312),
#  (51.2605918, 4.4221195),
#  (51.1795624, 4.3470642),
#  (51.2181444, 4.481195),
#  (51.3026909, 4.3683427),
#  (51.2890031, 4.3564003),
#  (51.1579145, 4.401706),
#  (51.2185297, 4.4207857),
#  (51.1947933, 4.3910327),
#  (51.1954973, 4.3901697),
#  (51.2140086, 4.44482),
#  (51.1913074, 4.388773),
#  (51.1953138, 4.388912),
#  (51.2056884, 4.4102319),
#  (51.2165962, 4.4044933),
#  (51.180127, 4.4304642),
#  (51.1526302, 4.383159),
#  (51.2002356, 4.4327143),
#  (51.2169691, 4.4207019),
#  (51.1815715, 4.3363358),
#  (51.1968852, 4.396798),
#  (51.2763963, 4.3624604),
#  (51.359347, 4.3117426),
#  (51.3242084, 4.2879939),
#  (51.3242084, 4.2879939),
#  (51.3242084, 4.2879939),
#  (51.1556391, 4.3772469),
#  (51.2312891, 4.450466),
#  (51.2118231, 4.3980983),
#  (51.1650496, 4.4089077),
#  (51.2503122, 4.3930785),
#  (51.1595891, 4.4068876),
#  (51.2303027, 4.4418148),
#  (51.2303027, 4.4418148),
#  (51.2141827, 4.4106068),
#  (51.1948449, 4.4117587),
#  (51.2640771, 4.3994951),
#  (51.2300817, 4.4064217),
#  (51.3134843, 4.3271114),
#  (51.3158137, 4.3327402),
#  (51.317435, 4.3439647),
#  (51.317435, 4.3439647),
#  (51.3168405, 4.3368564),
#  (51.3017705, 4.3385274),
#  (51.3067068, 4.33871),
#  (51.1988699, 4.4347381),
#  (51.1988699, 4.4347381),
#  (51.2697864, 4.3766281),
#  (51.2180888, 4.4091154),
#  (51.2840226, 4.3309429),
#  (51.2621393, 4.411522),
#  (51.1772983, 4.3893348),
#  (51.253462, 4.3506627),
#  (51.2569663, 4.3448672),
#  (51.1995502, 4.3589102),
#  (51.1867501, 4.3831592),
#  (51.2010021, 4.4352005),
#  (51.1869583, 4.3551345),
#  (51.2281815, 4.4122206),
#  (51.2134549, 4.4220529),
#  (51.2299283, 4.4177293),
#  (51.2523744, 4.4005987),
#  (51.2032621, 4.4121241),
#  (51.2066775, 4.3847647),
#  (51.2317165, 4.4096813),
#  (51.2037483, 4.4153398),
#  (51.296495, 4.4407177),
#  (51.1810751, 4.3819688),
#  (51.173874, 4.4259345),
#  (51.2056476, 4.3877966),
#  (51.2187094, 4.4152719),
#  (51.2213416, 4.3992856),
#  (51.2425057, 4.4417027),
#  (51.2536598, 4.4196185),
#  (51.2192347, 4.3591747),
#  (51.2302335, 4.4152679),
#  (51.2374882, 4.4175545),
#  (51.3087285, 4.3209836),
#  (51.1484938, 4.3809385),
#  (51.3191829, 4.3397072),
#  (51.2001149, 4.4353813),
#  (51.1855581, 4.4550409),
#  (51.214227, 4.4230825),
#  (51.2278187, 4.433718),
#  (51.2623092, 4.4595388),
#  (51.239442, 4.4557629),
#  (51.3418306, 4.2964605),
#  (51.2098583, 4.3889581),
#  (51.2039273, 4.3874428),
#  (51.2039273, 4.3874428),
#  (51.2192904, 4.4034402),
#  (51.2085373, 4.4026391),
#  (51.1886463, 4.3975016),
#  (51.2527128, 4.4559791),
#  (51.2609332, 4.4237818),
#  (51.349206, 4.3157869),
#  (51.1706746, 4.3910597),
#  (51.2045238, 4.3813541),
#  (51.2418928, 4.4527326),
#  (51.2130817, 4.4276616),
#  (51.1786276, 4.3600023),
#  (51.1691808, 4.3845143),
#  (51.2119865, 4.4530856),
#  (51.2011099, 4.4399205),
#  (51.2213416, 4.3992856),
#  (51.2213416, 4.3992856),
#  (51.2123661, 4.3954145),
#  (51.2104758, 4.4413143),
#  (51.2107762, 4.4739304),
#  (51.1839851, 4.3677569),
#  (51.2314295, 4.3860018),
#  (51.2023478, 4.3915901),
#  (51.1702544, 4.4016486),
#  (51.1793908, 4.4361224),
#  (51.1972179, 4.4509357),
#  (51.2217498, 4.3967751),
#  (51.2035073, 4.4270396),
#  (51.2274894, 4.4079615),
#  (51.2213416, 4.3992856),
#  (51.2058553, 4.398416),
#  (51.2189229, 4.3809554),
#  (51.2278277, 4.4194086),
#  (51.221595, 4.4278231),
#  (51.2075787, 4.4272195),
#  (51.2035548, 4.4207562),
#  (51.199353, 4.4594833),
#  (51.219216, 4.368471),
#  (51.1967421, 4.3759308),
#  (51.1606634, 4.3912692),
#  (51.1947713, 4.4436759),
#  (51.2249314, 4.3821976),
#  (51.2325834, 4.4324127),
#  (51.2318444, 4.4252966),
#  (51.2172848, 4.4825802),
#  (51.1948275, 4.3787726),
#  (51.2826743, 4.4292465),
#  (51.2916238, 4.4427988),
#  (51.2480605, 4.4211434),
#  (51.2509191, 4.4411045),
#  (51.2463099, 4.4427015),
#  (51.1886463, 4.3975016),
#  (51.1706746, 4.3910597),
#  (51.1649428, 4.3487435),
#  (51.1764096, 4.3535318),
#  (51.2307184, 4.4691193),
#  (51.2151264, 4.4344036),
#  (51.2474876, 4.4487635),
#  (51.2798314, 4.4130852),
#  (51.2092735, 4.4392368),
#  (51.2066094, 4.4595402),
#  (51.194447, 4.3787974),
#  (51.2375824, 4.4432288),
#  (51.2148918, 4.3959386),
#  (51.2511417, 4.4318931),
#  (51.1652924, 4.3893798),
#  (51.2422267, 4.441779),
#  (51.2135348, 4.4337105),
#  (51.1713264, 4.3538261),
#  (51.3442218, 4.3218754),
#  (51.2801802, 4.4315616),
#  (51.210828, 4.4180404),
#  (51.2213404, 4.4051485),
#  (51.1883201, 4.4266826),
#  (51.2203758, 4.4595994),
#  (51.2236802, 4.4140061),
#  (51.1762919, 4.3564278),
#  (51.1775194, 4.3918454),
#  (51.2170334, 4.4075924),
#  (51.1937706, 4.4352204),
#  (51.1928255, 4.4157228),
#  (51.2196237, 4.4121547),
#  (51.2299448, 4.4160739),
#  (51.23017, 4.4139014),
#  (51.2675012, 4.3888909),
#  (51.2697864, 4.3766281),
#  (51.2282225, 4.4393794),
#  (51.2717913, 4.3845025),
#  (51.2322058, 4.4110751),
#  (51.2033215, 4.4185293),
#  (51.2788358, 4.4496691),
#  (51.1638418, 4.400351),
#  (51.1624869, 4.3751028),
#  (51.2610806, 4.458164),
#  (51.1915297, 4.3799585),
#  (51.2514893, 4.4563176),
#  (51.1944817, 4.416519),
#  (51.1951703, 4.4215143),
#  (51.3044394, 4.2897551),
#  (51.2190356, 4.4599256),
#  (51.1932216, 4.3751036),
#  (51.227598, 4.4256872),
#  (51.2135576, 4.4536532),
#  (51.2801477, 4.4145161),
#  (51.2047385, 4.4545713),
#  (51.2068015, 4.381278),
#  (51.2528733, 4.3485327),
#  (51.3418306, 4.2964605),
#  (51.3148595, 4.3209569),
#  (51.2446161, 4.3518826),
#  (51.2412359, 4.4040071),
#  (51.2198771, 4.4011356),
#  (51.2312663, 4.417963),
#  (51.2023732, 4.3904895),
#  (51.2162156, 4.4107747),
#  (51.2231759, 4.4062723),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.2111145, 4.4228196),
#  (51.1955177, 4.433853),
#  (51.200631, 4.4358098),
#  (51.2617269, 4.4203774),
#  (51.2433442, 4.4432786),
#  (51.2244162, 4.3778698),
#  (51.1910161, 4.3796635),
#  (51.1749192, 4.3502134),
#  (51.1561896, 4.3602606),
#  (51.2185003, 4.4581206),
#  (51.1999968, 4.4341746),
#  (51.2000929, 4.4357706),
#  (51.2269388, 4.4276298),
#  (51.2142499, 4.4427781),
#  (51.3443021, 4.3215027),
#  (51.2608186, 4.4207663),
#  (51.2782133, 4.4196013),
#  (51.2302725, 4.4142116),
#  (51.2252335, 4.4152136),
#  (51.1613624, 4.3724878),
#  (51.2162675, 4.3973056),
#  (51.2272054, 4.406638),
#  (51.2248771, 4.3778378),
#  (51.3192653, 4.3487724),
#  (51.1716559, 4.3814717),
#  (51.2200897, 4.4130444),
#  (51.2974232, 4.3118681),
#  (51.2066951, 4.4629763),
#  (51.2066951, 4.4629763),
#  (51.2507044, 4.4195035),
#  (51.2602867, 4.4023597),
#  (51.2507044, 4.4195035),
#  (51.2055777, 4.3969526),
#  (51.2507044, 4.4195035),
#  (51.3192653, 4.3487724),
#  (51.2055777, 4.3969526),
#  (51.1716559, 4.3814717),
#  (51.2507044, 4.4195035),
#  (51.2248771, 4.3778378),
#  (51.2974232, 4.3118681),
#  (51.2507044, 4.4195035),
#  (51.2200897, 4.4130444),
#  (51.2507044, 4.4195035),
#  (51.2055777, 4.3969526),
#  (51.2085774, 4.3868378),
#  (51.2011809, 4.4349367),
#  (51.1945901, 4.4195113),
#  (51.2056884, 4.4102319),
#  (51.2890031, 4.3564003),
#  (51.2261505, 4.4061069),
#  (51.2204954, 4.4043023),
#  (51.2203342, 4.4119575),
#  (51.1926964, 4.4171852),
#  (51.1926964, 4.4171852),
#  (51.2276064, 4.4115963),
#  (51.2188559, 4.4319945),
#  (51.2391154, 4.4492653),
#  (51.1928344, 4.4167589),
#  (51.2331085, 4.3858419),
#  (51.359347, 4.3117426),
#  (51.211091, 4.3889501),
#  (51.1855581, 4.4550409),
#  (51.1952701, 4.419718),
#  (51.2190356, 4.4599256),
#  (51.2530294, 4.4221523),
#  (51.2744394, 4.4113211),
#  (51.283198, 4.42041),
#  (51.223609, 4.4694191),
#  (51.2234755, 4.3734174),
#  (51.1960132, 4.4269105),
#  (51.1891666, 4.3774967),
#  (51.1796025, 4.4289095),
#  (51.2324884, 4.4513074),
#  (51.2563718, 4.4494793),
#  (51.2048509, 4.4779063),
#  (51.1628264, 4.4023646),
#  (51.2237211, 4.413278),
#  (51.2848865, 4.3935929),
#  (51.2425418, 4.431535),
#  (51.221757, 4.4204917),
#  (51.3470942, 4.3304024),
#  (51.1751276, 4.3473573),
#  (51.2367147, 4.4037904),
#  (51.2263201, 4.4678947),
#  (51.1883028, 4.4285034),
#  (51.214984, 4.4853314),
#  (51.2509191, 4.4411045),
#  (51.2092735, 4.4392368),
#  (51.20539, 4.44568),
#  (51.2237337, 4.4581007),
#  (51.1878134, 4.436941),
#  (51.2058553, 4.398416),
#  (51.2025757, 4.4117883),
#  (51.2025757, 4.4117883),
#  (51.1951703, 4.4215143),
#  (51.2153041, 4.4068325),
#  (51.2210792, 4.3978819),
#  (51.1948275, 4.3787726),
#  (51.1563626, 4.4012945),
#  (51.194908, 4.4044371),
#  (51.1960117, 4.4624844),
#  (51.2283706, 4.4565487),
#  (51.1801619, 4.3415735),
#  (51.2125047, 4.4103918),
#  (51.2149856, 4.4071035),
#  (51.2217763, 4.348097),
#  (51.234858, 4.3932715),
#  (51.1991376, 4.3742791),
#  (51.1569647, 4.3893802),
#  (51.1911829, 4.4498723),
#  (51.200631, 4.4358098),
#  (51.3493748, 4.3296395),
#  (51.2122784, 4.4064781),
#  (51.3158137, 4.3327402),
#  (51.3197959, 4.3455093),
#  (51.1939964, 4.4115835),
#  (51.1568097, 4.3776772),
#  (51.1847602, 4.3740291),
#  (51.1786635, 4.4239083)]

# %%
def calculate_distance_matrices(city_name, data_files):
    # Extract AEDs, cards, and vehicles coordinates directly from the data_files dictionary
    aeds_coordinates = data_files[f"{city_name}_aeds.csv"]["geometry"].tolist()[:10]
    cards_coordinates = data_files[f"{city_name}_cards.csv"]["geometry"].tolist()[:10]
    vehicles_coordinates = data_files[f"{city_name}_vehicles.csv"]["geometry"].tolist()[:10]

    # Calculate the distance matrix using Google Maps API for AEDs to cards
    aeds_to_cards_matrix = gmaps.distance_matrix(aeds_coordinates, cards_coordinates, mode='walking', units='metric')

    # Calculate the distance matrix using Google Maps API for vehicles to cards
    vehicles_to_cards_matrix = gmaps.distance_matrix(vehicles_coordinates, cards_coordinates, mode='walking', units='metric')

    return aeds_to_cards_matrix, vehicles_to_cards_matrix

# Example usage
city_name = 'Antwerpen'  # Replace with the desired city name
aeds_to_cards_matrix, vehicles_to_cards_matrix = calculate_distance_matrices(city_name, data_files)

print("Distance matrix from AEDs to Cards:")
print(aeds_to_cards_matrix)

print("\nDistance matrix from Vehicles to Cards:")
print(vehicles_to_cards_matrix)
# Out:
# Distance matrix from AEDs to Cards:
# {'destination_addresses': ['Van Amstelstraat 24, 2100 Antwerpen, Belgium', 'Van Amstelstraat 24, 2100 Antwerpen, Belgium', 'Nieuwdreef 138a, 2170 Antwerpen, Belgium', 'Nieuwdreef 138a, 2170 Antwerpen, Belgium', 'Driehoekstraat 97, 2180 Antwerpen, Belgium', 'Driehoekstraat 97, 2180 Antwerpen, Belgium', 'Simonsstraat 28, 2018 Antwerpen, Belgium', 'Rozenkransplein 12, 2610 Antwerpen, Belgium', 'Rozenkransplein 12, 2610 Antwerpen, Belgium', 'N177 181, 2610 Antwerpen, Belgium'], 'origin_addresses': ['Uitbreidingstraat 354, 2600 Antwerpen, Belgium', 'Adriaan Brouwerstraat 24, 2000 Antwerpen, Belgium', 'Slachthuislaan 74, 2060 Antwerpen, Belgium', 'Weerstandlaan 24, 2660 Antwerpen, Belgium', 'Lamorinierestraat 135, 2018 Antwerpen, Belgium', 'Roderveldlaan 5, 2600 Antwerpen, Belgium', 'Laarstraat 16, 2610 Antwerpen, Belgium', 'Hallo, 2610 Antwerpen, Belgium', 'Boomsesteenweg 957, 2610 Antwerpen, Belgium', 'Boomsesteenweg 957, 2610 Antwerpen, Belgium'], 'rows': [{'elements': [{'distance': {'text': '5.1 km', 'value': 5060}, 'duration': {'text': '1 hour 11 mins', 'value': 4244}, 'status': 'OK'}, {'distance': {'text': '5.1 km', 'value': 5060}, 'duration': {'text': '1 hour 11 mins', 'value': 4244}, 'status': 'OK'}, {'distance': {'text': '6.9 km', 'value': 6919}, 'duration': {'text': '1 hour 36 mins', 'value': 5782}, 'status': 'OK'}, {'distance': {'text': '6.9 km', 'value': 6919}, 'duration': {'text': '1 hour 36 mins', 'value': 5782}, 'status': 'OK'}, {'distance': {'text': '10.4 km', 'value': 10441}, 'duration': {'text': '2 hours 23 mins', 'value': 8587}, 'status': 'OK'}, {'distance': {'text': '10.4 km', 'value': 10441}, 'duration': {'text': '2 hours 23 mins', 'value': 8587}, 'status': 'OK'}, {'distance': {'text': '2.0 km', 'value': 2018}, 'duration': {'text': '28 mins', 'value': 1668}, 'status': 'OK'}, {'distance': {'text': '4.0 km', 'value': 3994}, 'duration': {'text': '56 mins', 'value': 3354}, 'status': 'OK'}, {'distance': {'text': '4.0 km', 'value': 3994}, 'duration': {'text': '56 mins', 'value': 3354}, 'status': 'OK'}, {'distance': {'text': '4.7 km', 'value': 4688}, 'duration': {'text': '1 hour 6 mins', 'value': 3957}, 'status': 'OK'}]}, {'elements': [{'distance': {'text': '3.5 km', 'value': 3491}, 'duration': {'text': '49 mins', 'value': 2931}, 'status': 'OK'}, {'distance': {'text': '3.5 km', 'value': 3491}, 'duration': {'text': '49 mins', 'value': 2931}, 'status': 'OK'}, {'distance': {'text': '4.6 km', 'value': 4581}, 'duration': {'text': '1 hour 3 mins', 'value': 3799}, 'status': 'OK'}, {'distance': {'text': '4.6 km', 'value': 4581}, 'duration': {'text': '1 hour 3 mins', 'value': 3799}, 'status': 'OK'}, {'distance': {'text': '7.4 km', 'value': 7364}, 'duration': {'text': '1 hour 41 mins', 'value': 6046}, 'status': 'OK'}, {'distance': {'text': '7.4 km', 'value': 7364}, 'duration': {'text': '1 hour 41 mins', 'value': 6046}, 'status': 'OK'}, {'distance': {'text': '2.5 km', 'value': 2544}, 'duration': {'text': '35 mins', 'value': 2093}, 'status': 'OK'}, {'distance': {'text': '6.1 km', 'value': 6088}, 'duration': {'text': '1 hour 25 mins', 'value': 5090}, 'status': 'OK'}, {'distance': {'text': '6.1 km', 'value': 6088}, 'duration': {'text': '1 hour 25 mins', 'value': 5090}, 'status': 'OK'}, {'distance': {'text': '6.7 km', 'value': 6655}, 'duration': {'text': '1 hour 32 mins', 'value': 5538}, 'status': 'OK'}]}, {'elements': [{'distance': {'text': '1.0 km', 'value': 961}, 'duration': {'text': '14 mins', 'value': 819}, 'status': 'OK'}, {'distance': {'text': '1.0 km', 'value': 961}, 'duration': {'text': '14 mins', 'value': 819}, 'status': 'OK'}, {'distance': {'text': '2.8 km', 'value': 2820}, 'duration': {'text': '39 mins', 'value': 2357}, 'status': 'OK'}, {'distance': {'text': '2.8 km', 'value': 2820}, 'duration': {'text': '39 mins', 'value': 2357}, 'status': 'OK'}, {'distance': {'text': '6.9 km', 'value': 6942}, 'duration': {'text': '1 hour 35 mins', 'value': 5709}, 'status': 'OK'}, {'distance': {'text': '6.9 km', 'value': 6942}, 'duration ...
#
# Distance matrix from Vehicles to Cards:
# {'destination_addresses': ['Van Amstelstraat 24, 2100 Antwerpen, Belgium', 'Van Amstelstraat 24, 2100 Antwerpen, Belgium', 'Nieuwdreef 138a, 2170 Antwerpen, Belgium', 'Nieuwdreef 138a, 2170 Antwerpen, Belgium', 'Driehoekstraat 97, 2180 Antwerpen, Belgium', 'Driehoekstraat 97, 2180 Antwerpen, Belgium', 'Simonsstraat 28, 2018 Antwerpen, Belgium', 'Rozenkransplein 12, 2610 Antwerpen, Belgium', 'Rozenkransplein 12, 2610 Antwerpen, Belgium', 'N177 181, 2610 Antwerpen, Belgium'], 'origin_addresses': ['Gijselsstraat 150, 2140 Antwerpen, Belgium', 'Antwerpse Steenweg 242, 2660 Antwerpen, Belgium', 'August Vermeylenlaan 6, 2050 Antwerpen, Belgium', 'Antwerpsebaan 4, 2040 Antwerpen, Belgium', 'Leopoldstraat 26, 2000 Antwerpen, Belgium', 'Paleisstraat 121, 2018 Antwerpen, Belgium', 'Florent Pauwelslei 1, 2100 Antwerpen, Belgium', 'ZNA Jan Palfijn, Lange Bremstraat 70, 2170 Antwerpen, Belgium', 'N173 214, 2600 Antwerpen, Belgium', 'Sint-Vincentiusstraat 20, 2018 Antwerpen, Belgium'], 'rows': [{'elements': [{'distance': {'text': '2.5 km', 'value': 2466}, 'duration': {'text': '34 mins', 'value': 2069}, 'status': 'OK'}, {'distance': {'text': '2.5 km', 'value': 2466}, 'duration': {'text': '34 mins', 'value': 2069}, 'status': 'OK'}, {'distance': {'text': '4.3 km', 'value': 4325}, 'duration': {'text': '1 hour 0 mins', 'value': 3607}, 'status': 'OK'}, {'distance': {'text': '4.3 km', 'value': 4325}, 'duration': {'text': '1 hour 0 mins', 'value': 3607}, 'status': 'OK'}, {'distance': {'text': '8.7 km', 'value': 8662}, 'duration': {'text': '1 hour 59 mins', 'value': 7118}, 'status': 'OK'}, {'distance': {'text': '8.7 km', 'value': 8662}, 'duration': {'text': '1 hour 59 mins', 'value': 7118}, 'status': 'OK'}, {'distance': {'text': '2.1 km', 'value': 2075}, 'duration': {'text': '28 mins', 'value': 1707}, 'status': 'OK'}, {'distance': {'text': '6.4 km', 'value': 6367}, 'duration': {'text': '1 hour 30 mins', 'value': 5370}, 'status': 'OK'}, {'distance': {'text': '6.4 km', 'value': 6367}, 'duration': {'text': '1 hour 30 mins', 'value': 5370}, 'status': 'OK'}, {'distance': {'text': '6.9 km', 'value': 6885}, 'duration': {'text': '1 hour 37 mins', 'value': 5810}, 'status': 'OK'}]}, {'elements': [{'distance': {'text': '9.0 km', 'value': 9047}, 'duration': {'text': '2 hours 6 mins', 'value': 7574}, 'status': 'OK'}, {'distance': {'text': '9.0 km', 'value': 9047}, 'duration': {'text': '2 hours 6 mins', 'value': 7574}, 'status': 'OK'}, {'distance': {'text': '10.9 km', 'value': 10879}, 'duration': {'text': '2 hours 31 mins', 'value': 9071}, 'status': 'OK'}, {'distance': {'text': '10.9 km', 'value': 10879}, 'duration': {'text': '2 hours 31 mins', 'value': 9071}, 'status': 'OK'}, {'distance': {'text': '13.7 km', 'value': 13687}, 'duration': {'text': '3 hours 9 mins', 'value': 11344}, 'status': 'OK'}, {'distance': {'text': '13.7 km', 'value': 13687}, 'duration': {'text': '3 hours 9 mins', 'value': 11344}, 'status': 'OK'}, {'distance': {'text': '6.1 km', 'value': 6137}, 'duration': {'text': '1 hour 25 mins', 'value': 5119}, 'status': 'OK'}, {'distance': {'text': '2.9 km', 'value': 2877}, 'duration': {'text': '40 mins', 'value': 2385}, 'status': 'OK'}, {'distance': {'text': '2.9 km', 'value': 2877}, 'duration': {'text': '40 mins', 'value': 2385}, 'status': 'OK'}, {'distance': {'text': '2.5 km', 'value': 2478}, 'duration': {'text': '34 mins', 'value': 2046}, 'status': 'OK'}]}, {'elements': [{'distance': {'text': '7.0 km', 'value': 6974}, 'duration': {'text': '1 hour 36 mins', 'value': 5770}, 'status': 'OK'}, {'distance': {'text': '7.0 km', 'value': 6974}, 'duration': {'text': '1 hour 36 mins', 'value': 5770}, 'status': 'OK'}, {'distance': {'text': '8.4 km', 'value': 8416}, 'duration': {'text': '1 hour 55 mins', 'value': 6911}, 'status': 'OK'}, {'distance': {'text': '8.4 km', 'value': 8416}, 'duration': {'text': '1 hour 55 mins', 'value': 6911}, 'status': 'OK'}, {'distance': {'text': '10.9 km', 'value': 10900}, 'duration': {'text': '2 hours 28 mins', 'value': 8909}, 'sta ...
